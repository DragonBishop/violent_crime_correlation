# %% [markdown]
# # Data Analysis Report
# *Subtitle for Report*
#
# ## Executive Summary
#
# ### Project Task
#
# ### Key Findings
#
# ### Top Three Recommendations
#
# ### Project Context
#
# ### Project Objective
#
# ### Key Questions

# %% [markdown]
# ## Data Integrity
#
# *Provide a 2-3 sentence synposis of the data's integrity*
#
# ### Data Source
#
# #### Initial Dataset Size
#
# #### Data Dictionary
#
# ### Limitations

# %% [markdown]
# ## Data Processing
#
# ### Tools Used
#
# ### Processing Methodology
#
# ### Processing Results
#
# #### Dirty Data and Outliers
#
# #### Clean Data Overview

# %% [markdown]
# ### Cleaning Log

# %% [markdown]
# ## Data Analysis
#
# ### Analysis Methodology
#
# ### Analysis Findings
#
# *Include subtitles for key themes or visualizations*
#
# ### Conclusions

# %% [markdown]
# ## Appendices
#
# ### Reflection
#
# #### Skills Demonstrated
#
# ### Cleaning Log
